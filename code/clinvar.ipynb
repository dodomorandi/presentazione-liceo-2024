# %%
import pandas

data = pandas.read_table("/tmp/clinvar_result.txt")

# %%
variant_types = data.value_counts('Variant type')
variant_types.plot(kind='bar')
# Out:
# <Axes: xlabel='Variant type'>

# %%
data["Gene(s)"].map(lambda genes: genes.split("|")).explode()
# Out:
# 0        LOC112533659
# 0        LOC112533660
# 0        LOC112533661
# 0        LOC112533662
# 0        LOC112533663
#              ...
# 14660           BRCA1
# 14661           BRCA1
# 14662           BRCA1
# 14663           BRCA1
# 14664           BRCA1
# Name: Gene(s), Length: 23534, dtype: object
